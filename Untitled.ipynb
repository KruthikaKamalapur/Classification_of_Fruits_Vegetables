# %%
import pandas as pd 
import numpy as np

# %%
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img,img_to_array
print(tf.__version__)
# Out:
# 2.18.0

# %%
train_dir = Path('train')
train_filepaths = list(train_dir.glob(r'**/*.jpg'))

# %%
test_dir = Path('test')
test_filepaths = list(test_dir.glob(r'**/*.jpg'))

# %%
val_dir = Path('validation')
val_filepaths = list(test_dir.glob(r'**/*.jpg'))

# %%
import os
import pandas as pd

def image_processing(filepath):
    """ Create a DataFrame with the filepath and the labels of the pictures """
    
    if not filepath:
        raise ValueError("The filepath list is empty.")
    
    labels = []
    for i in range(len(filepath)):
        parts = os.path.normpath(filepath[i]).split(os.sep)
        if len(parts) < 2:
            raise ValueError(f"Filepath {filepath[i]} does not have enough directory levels to extract a label.")
        labels.append(parts[-2])
    
    filepath_series = pd.Series(filepath, name='Filepath').astype(str)
    labels_series = pd.Series(labels, name='Label')

    # Concatenate filepaths and labels
    df = pd.concat([filepath_series, labels_series], axis=1)

    # Shuffle the DataFrame and reset index
    df = df.sample(frac=1).reset_index(drop=True)
    
    return df

# %%
train_df = image_processing(train_filepaths)
test_df = image_processing(test_filepaths)
val_df = image_processing(val_filepaths)

# %%
print('-- Training set --\n')
print(f'Number of pictures: {train_df.shape[0]}\n')
print(f'Number of different labels: {len(train_df.Label.unique())}\n')
print(f'Labels: {train_df.Label.unique()}')
# Out:
# -- Training set --
#
# Number of pictures: 2855
#
# Number of different labels: 36
#
# Labels: ['potato' 'raddish' 'pomegranate' 'capsicum' 'jalepeno' 'onion'
#  'chilli pepper' 'tomato' 'cucumber' 'corn' 'lemon' 'cauliflower'
#  'sweetcorn' 'ginger' 'cabbage' 'spinach' 'watermelon' 'garlic' 'kiwi'
#  'paprika' 'soy beans' 'pineapple' 'banana' 'grapes' 'beetroot'
#  'sweetpotato' 'lettuce' 'turnip' 'mango' 'carrot' 'orange' 'pear'
#  'bell pepper' 'eggplant' 'apple' 'peas']

# %%
train_df.head(5)
# Out:
#                          Filepath        Label
# 0       train\potato\Image_11.jpg       potato
# 1      train\raddish\Image_37.jpg      raddish
# 2  train\pomegranate\Image_33.jpg  pomegranate
# 3     train\capsicum\Image_82.jpg     capsicum
# 4     train\jalepeno\Image_72.jpg     jalepeno

# %%
# Create a DataFrame with one Label of each category
df_unique = train_df.copy().drop_duplicates(subset=["Label"]).reset_index()

# Display some pictures of the dataset
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(8, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df_unique.Filepath[i]))
    ax.set_title(df_unique.Label[i], fontsize = 12)
plt.tight_layout(pad=0.5)
plt.show()

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 2855 validated image filenames belonging to 36 classes.

# %%
val_images = train_generator.flow_from_dataframe(
    dataframe=val_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 340 validated image filenames belonging to 36 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 340 validated image filenames belonging to 36 classes.

# %%
pretrained_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)
pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(36, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=val_images,
    batch_size = 32,
    epochs=5,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3480 - loss: 2.5168
# C:\Users\KRUTHIKA\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.3501 - loss: 2.5077 - val_accuracy: 0.8441 - val_loss: 0.4616
# Epoch 2/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.8127 - loss: 0.6262 - val_accuracy: 0.9176 - val_loss: 0.2651
# Epoch 3/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9071 - loss: 0.3119 - val_accuracy: 0.9382 - val_loss: 0.1980
# Epoch 4/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.9348 - loss: 0.2097 - val_accuracy: 0.9382 - val_loss: 0.1922
# ...

# %%
print("Classes in training set:", set(train_df['Label'].unique()))
print("Classes in validation set:", set(val_df['Label'].unique()))
print("Classes in test set:", set(test_df['Label'].unique()))
# Out:
# Classes in training set: {'spinach', 'paprika', 'banana', 'orange', 'eggplant', 'lemon', 'peas', 'capsicum', 'carrot', 'apple', 'ginger', 'pear', 'pomegranate', 'corn', 'watermelon', 'mango', 'cabbage', 'chilli pepper', 'sweetcorn', 'bell pepper', 'raddish', 'cauliflower', 'garlic', 'pineapple', 'turnip', 'jalepeno', 'grapes', 'soy beans', 'tomato', 'sweetpotato', 'lettuce', 'cucumber', 'beetroot', 'kiwi', 'onion', 'potato'}
# Classes in validation set: {'spinach', 'paprika', 'banana', 'orange', 'eggplant', 'peas', 'lemon', 'capsicum', 'carrot', 'apple', 'ginger', 'pear', 'pomegranate', 'corn', 'mango', 'watermelon', 'cabbage', 'chilli pepper', 'sweetcorn', 'bell pepper', 'raddish', 'cauliflower', 'garlic', 'pineapple', 'turnip', 'jalepeno', 'grapes', '.ipynb_checkpoints', 'soy beans', 'sweetpotato', 'tomato', 'lettuce', 'cucumber', 'beetroot', 'kiwi', 'onion', 'potato'}
# ...

# %%
extra_classes_in_val = set(val_df['Label'].unique()) - set(train_df['Label'].unique())
extra_classes_in_test = set(test_df['Label'].unique()) - set(train_df['Label'].unique())
print("Extra classes in validation set:", extra_classes_in_val)
print("Extra classes in test set:", extra_classes_in_test)
# Out:
# Extra classes in validation set: {'.ipynb_checkpoints'}
# Extra classes in test set: {'.ipynb_checkpoints'}

# %%
val_df = val_df[val_df['Label'].isin(train_df['Label'].unique())]
test_df = test_df[test_df['Label'].isin(train_df['Label'].unique())]

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)
# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred1 = [labels[k] for k in pred]
pred1
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step
# ['pineapple',
#  'spinach',
#  'mango',
#  'watermelon',
#  'pomegranate',
#  'watermelon',
#  'lettuce',
#  'soy beans',
#  'bell pepper',
#  'watermelon',
#  'jalepeno',
#  'cauliflower',
#  'raddish',
#  'potato',
#  'corn',
#  'banana',
#  'eggplant',
#  'mango',
#  'cucumber',
#  'cauliflower',
#  'turnip',
#  'cabbage',
#  'mango',
#  'mango',
#  'onion',
#  'jalepeno',
#  'capsicum',
#  'watermelon',
#  'garlic',
#  'raddish',
#  'lettuce',
#  'garlic',
#  'pear',
#  'beetroot',
#  'chilli pepper',
#  'garlic',
#  'pomegranate',
#  'potato',
#  'onion',
#  'bell pepper',
#  'pomegranate',
#  'garlic',
#  'cucumber',
#  'onion',
#  'bell pepper',
#  'orange',
#  'beetroot',
#  'pomegranate',
#  'paprika',
#  'kiwi',
#  'sweetcorn',
#  'eggplant',
#  'grapes',
#  'capsicum',
#  'tomato',
#  'pineapple',
#  'jalepeno',
#  'pineapple',
#  'carrot',
#  'kiwi',
#  'lettuce',
#  'beetroot',
#  'garlic',
#  'raddish',
#  'orange',
# ...

# %%
def output(location):
    img=load_img(location,target_size=(224,224,3))
    img=img_to_array(img)
    img=img/255
    img=np.expand_dims(img,[0])
    answer=model.predict(img)
    y_class = answer.argmax(axis=-1)
    y = " ".join(str(x) for x in y_class)
    y = int(y)
    res = labels[y]
    return res

# %%
img = output('test/cabbage/Image_1.jpg')
img
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 'cabbage'

# %%
model.save('FV.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
